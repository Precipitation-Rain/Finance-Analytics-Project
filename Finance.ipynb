# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('finance_transactions.csv')

# %% [markdown]
# # Data Wrangling

# %%
df.head()
# Out:
#   transaction_id transaction_date account_id customer_id transaction_type  \
# 0      T00000001       21-02-2025    A001795      C00629       Investment
# 1      T00000002       28-01-2023    A004859      C02038         Transfer
# 2      T00000003       25-06-2024    A003081      C00652         Transfer
# 3      T00000004       20-02-2025    A004122      C01357       Withdrawal
# 4      T00000005       06-08-2024    A004150      C02547          Deposit
#
#           channel merchant_category    amount  fee_amount  tax_amount  \
# 0      Mobile App     Food Delivery  24721.24      123.61       22.25
# 1             UPI         Groceries  18711.77       93.56       16.84
# 2     Net Banking         Groceries  45865.90        0.00        0.00
# 3      Auto Debit            Salary   4310.91         NaN        0.78
# 4          Branch          Shopping  11646.45        0.00        0.00
#
#   currency transaction_status is_fraud  risk_score   reference_no
# ...

# %%
df.tail()
# Out:
#       transaction_id transaction_date account_id customer_id transaction_type  \
# 50064      T00049879       01-09-2024    A006793      C02066         Transfer
# 50065      T00049880       27-06-2025    A003754      C01053         Loan EMI
# 50066      T00049881       02-08-2024    A003657      C02434         Loan EMI
# 50067      T00049882       13-11-2023    A003840      C03287         Transfer
# 50068      T00049883       25-02-2025    A007128      C03308     Bill Payment
#
#            channel merchant_category    amount  fee_amount  tax_amount  \
# 50064  Net Banking          Shopping  11386.50       22.77        4.10
# 50065          ATM     Entertainment  40959.94       81.92       14.75
# 50066          ATM         Education   9873.84        9.87        1.78
# 50067          UPI            Salary  13980.12        0.00        0.00
# 50068  Net Banking      Bank Charges   2780.85        2.78        0.50
#
#       currency transaction_status is_fraud  risk_score   reference_no
# ...

# %%
df.sample(10)
# Out:
#       transaction_id transaction_date account_id customer_id transaction_type  \
# 41010      T00041007       02-04-2023    A006930      C02685     Card Payment
# 36348      T00036345       22-08-2024    A001983      C03368         Loan EMI
# 36038      T00036035       28-08-2025    A001319      C02607       Withdrawal
# 31808      T00031805       21-08-2023    A004679      C01688           Refund
# 38399      T00038396       21-08-2025    A000842      C00866     Card Payment
# 43033      T00043030       19-11-2025    A005939      C04154       Investment
# 19622      T00019619       25-06-2025    A005889      C02329         Transfer
# 39645      T00039642       22-09-2024    A000626      C01355         Loan EMI
# 4309       T00004306       12-06-2024    A007940      C01031         Loan EMI
# 19715      T00019712       26-06-2023    A004514      C03355         Loan EMI
#
#            channel merchant_category    amount  fee_amount  tax_amount  \
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'account_id', 'customer_id',
#        'transaction_type', 'channel', 'merchant_category', 'amount',
#        'fee_amount', 'tax_amount', 'currency', 'transaction_status',
#        'is_fraud', 'risk_score', 'reference_no'],
#       dtype='object')

# %%
df.dtypes
# Out:
# transaction_id         object
# transaction_date       object
# account_id             object
# customer_id            object
# transaction_type       object
# channel                object
# merchant_category      object
# amount                float64
# fee_amount            float64
# tax_amount            float64
# currency               object
# transaction_status     object
# is_fraud               object
# risk_score              int64
# reference_no           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# transaction_id         0
# transaction_date       0
# account_id             0
# customer_id            0
# transaction_type       0
# channel                0
# merchant_category      0
# amount                 0
# fee_amount            24
# tax_amount             0
# currency               0
# transaction_status     0
# is_fraud               0
# risk_score             0
# reference_no           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(68)

# %%
df[df.duplicated()]
# Out:
#       transaction_id transaction_date account_id customer_id transaction_type  \
# 15         T00000014       10-08-2024    A004138      C00960         Loan EMI
# 67         T00000065       26-02-2023    A006060      C00103          Deposit
# 139        T00000136       18-03-2026    A003806      C03104         Transfer
# 50004      T00049983       08-01-2025    A006536      C04304       Fee Charge
# 50005      T00049984       27-12-2025    A001626      C02778          Deposit
# ...              ...              ...        ...         ...              ...
# 50064      T00049879       01-09-2024    A006793      C02066         Transfer
# 50065      T00049880       27-06-2025    A003754      C01053         Loan EMI
# 50066      T00049881       02-08-2024    A003657      C02434         Loan EMI
# 50067      T00049882       13-11-2023    A003840      C03287         Transfer
# 50068      T00049883       25-02-2025    A007128      C03308     Bill Payment
#
# ...

# %%
df2 = pd.read_csv("customers.csv")

# %%
df2.head()
# Out:
#   customer_id fisrt_name second_name  gender date_of_birth        city  \
# 0      C00001      Karan      Chopra    Male    09-10-1982     Kolkata
# 1      C00002     Ishaan       Patel    Male    07-10-1983  Chandigarh
# 2      C00003    Krishna       Patel    Male    27-11-1989   Hyderabad
# 3      C00004       Amit       Verma    Male    13-08-1970     Lucknow
# 4      C00005    Reyansh        Jain  Female    07-02-1977   Ahmedabad
#
#            state  occupation customer_segment  annual_income   join_date
# 0    West Bengal     Retired              SME      988416.79  15-04-2021
# 1     Chandigarh    Salaried          Premium      457149.28  06-04-2022
# 2      Telangana     Retired           Retail      378907.24  06-03-2026
# 3  Uttar Pradesh    Salaried           Retail      299085.16  16-07-2021
# 4        Gujarat  Freelancer              SME      775436.07  23-02-2023

# %%
df2.tail()
# Out:
#      customer_id fisrt_name second_name  gender date_of_birth       city  \
# 4995      C04996       Pari      Kapoor    Male    06-11-2002  Hyderabad
# 4996      C04997      Rohan    Malhotra  Female    01-01-1975     Bhopal
# 4997      C04998        Ira     Agarwal  Female    10-12-1976    Lucknow
# 4998      C04999      Sneha       Joshi  Female    03-04-1994      Kochi
# 4999      C05000      Anika       Patel  Female    26-11-2003     Nagpur
#
#                state      occupation customer_segment  annual_income  \
# 4995       Telangana  Business Owner           Retail      279631.80
# 4996  Madhya Pradesh  Business Owner           Retail      869312.76
# 4997   Uttar Pradesh   Self Employed          Premium     3571015.01
# 4998          Kerala        Salaried              SME     1046872.92
# 4999     Maharashtra      Freelancer           Retail     1017717.21
#
#        join_date
# 4995  06-11-2021
# 4996  20-07-2022
# 4997  03-04-2021
# 4998  28-07-2023
# 4999  25-04-2023

# %%
df2.sample(10)
# Out:
#      customer_id fisrt_name second_name  gender date_of_birth        city  \
# 195       C00196      Kiara      Bansal    Male    02-08-1995       Surat
# 2557      C02558     Aadhya    Malhotra    Male    02-11-1988  Chandigarh
# 2349      C02350    Krishna      Kapoor  Female    21-08-1960        Pune
# 1474      C01475      Kabir       Gupta  Female    23-10-1986        Pune
# 2103      C02104    Reyansh      Bansal  Female    18-10-2000      Bhopal
# 3487      C03488      Priya    Kulkarni  Female    19-09-1963    Gurugram
# 793       C00794      Sneha        Iyer  Female    22-07-1992      Indore
# 3949      C03950      Rohan       Joshi    Male    15-04-2001      Mysuru
# 274       C00275       Myra       Verma    Male    15-11-1972   Bengaluru
# 2260      C02261      Anaya    Kulkarni  Female    28-04-1981  Coimbatore
#
#                state      occupation customer_segment  annual_income  \
# 195          Gujarat  Business Owner           Wealth     1971778.35
# ...

# %%
df2.isnull().sum()
# Out:
# customer_id         0
# fisrt_name          0
# second_name         0
# gender              0
# date_of_birth       0
# city                0
# state               0
# occupation          0
# customer_segment    0
# annual_income       0
# join_date           0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2.dtypes
# Out:
# customer_id          object
# fisrt_name           object
# second_name          object
# gender               object
# date_of_birth        object
# city                 object
# state                object
# occupation           object
# customer_segment     object
# annual_income       float64
# join_date            object
# dtype: object

# %%
df2.columns
# Out:
# Index(['customer_id', 'fisrt_name', 'second_name', 'gender', 'date_of_birth',
#        'city', 'state', 'occupation', 'customer_segment', 'annual_income',
#        'join_date'],
#       dtype='object')

# %% [markdown]
# # Data Clening

# %%
df['fee_amount'].isna().sum()
# Out:
# np.int64(24)

# %%
df['fee_amount'] = df['fee_amount'].fillna(df['fee_amount'].mean())

# %%
df['currency'] = df['currency'].str.upper()

# %%
df['transaction_date'] = df['transaction_date'].astype('datetime64[ns]')

# %%
df2.dtypes
# Out:
# customer_id          object
# fisrt_name           object
# second_name          object
# gender               object
# date_of_birth        object
# city                 object
# state                object
# occupation           object
# customer_segment     object
# annual_income       float64
# join_date            object
# dtype: object

# %%
df2[['join_date' , 'date_of_birth']] = df2[['join_date' , 'date_of_birth']].astype('datetime64[ns]')

# %%
df2.dtypes
# Out:
# customer_id                 object
# fisrt_name                  object
# second_name                 object
# gender                      object
# date_of_birth       datetime64[ns]
# city                        object
# state                       object
# occupation                  object
# customer_segment            object
# annual_income              float64
# join_date           datetime64[ns]
# dtype: object

# %%
df2.rename(columns={'fisrt_name' :'first_name'} , inplace=True)

# %%
df2['customer_name'] = df2['first_name'] + " " + df2['second_name']

# %%
df2.drop(columns=['first_name' , 'second_name'] , inplace=True)

# %%
df2
# Out:
#      customer_id  gender date_of_birth        city           state  \
# 0         C00001    Male    1982-09-10     Kolkata     West Bengal
# 1         C00002    Male    1983-07-10  Chandigarh      Chandigarh
# 2         C00003    Male    1989-11-27   Hyderabad       Telangana
# 3         C00004    Male    1970-08-13     Lucknow   Uttar Pradesh
# 4         C00005  Female    1977-07-02   Ahmedabad         Gujarat
# ...          ...     ...           ...         ...             ...
# 4995      C04996    Male    2002-06-11   Hyderabad       Telangana
# 4996      C04997  Female    1975-01-01      Bhopal  Madhya Pradesh
# 4997      C04998  Female    1976-10-12     Lucknow   Uttar Pradesh
# 4998      C04999  Female    1994-03-04       Kochi          Kerala
# 4999      C05000  Female    2003-11-26      Nagpur     Maharashtra
#
#           occupation customer_segment  annual_income  join_date  \
# 0            Retired              SME      988416.79 2021-04-15
# ...

# %%
df
# Out:
#       transaction_id transaction_date account_id customer_id transaction_type  \
# 0          T00000001       2025-02-21    A001795      C00629       Investment
# 1          T00000002       2023-01-28    A004859      C02038         Transfer
# 2          T00000003       2024-06-25    A003081      C00652         Transfer
# 3          T00000004       2025-02-20    A004122      C01357       Withdrawal
# 4          T00000005       2024-06-08    A004150      C02547          Deposit
# ...              ...              ...        ...         ...              ...
# 50064      T00049879       2024-01-09    A006793      C02066         Transfer
# 50065      T00049880       2025-06-27    A003754      C01053         Loan EMI
# 50066      T00049881       2024-02-08    A003657      C02434         Loan EMI
# 50067      T00049882       2023-11-13    A003840      C03287         Transfer
# 50068      T00049883       2025-02-25    A007128      C03308     Bill Payment
#
# ...

# %% [markdown]
# # Creating New Table

# %%
start_date = df['transaction_date'].min()
end_date = df['transaction_date'].max()
all_dates = pd.date_range(df['transaction_date'].min() , df['transaction_date'].max() , freq='D')

# %%
calender = pd.DataFrame({'Date' : all_dates})

# %%
calender
# Out:
#            Date
# 0    2023-01-01
# 1    2023-01-02
# 2    2023-01-03
# 3    2023-01-04
# 4    2023-01-05
# ...         ...
# 1429 2026-11-30
# 1430 2026-12-01
# 1431 2026-12-02
# 1432 2026-12-03
# 1433 2026-12-04
#
# [1434 rows x 1 columns]
